# %%
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Input
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from keras.utils import to_categorical
from tqdm.notebook import tqdm as tqdm
from tensorflow.keras import Model
from keras.models import Sequential
from sklearn.utils import shuffle
from keras import models, layers
from datetime import datetime
from tensorflow import keras
from keras import backend as K

import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import pandas as pd
import numpy as np
import json
import cv2
import os
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/pandas/core/nanops.py:38: UserWarning: The installed version of bottleneck 0.7.0 is not supported in pandas and will be not be used
# The minimum supported version is 1.0.0
#
#   ver=ver, min_ver=_MIN_BOTTLENECK_VERSION), UserWarning)

# %% [markdown]
# # Loading Dataset

# %%
mapping_data = json.load(open("/root/notebooks/0858611-2/tooth_xray/model/dataset/Dental_Data/PBL/10_seg/mapping.json", "r"))
filter_data  = { path: max(list(map(int, state))) for path, state in mapping_data.items() if max(list(map(int, state))) >= 0 }

# %%
def json_2_dataframe_PBL(dataframe, data):
        for path, state in tqdm(data.items()):
                item = { "Path": path, "Class": 0 if state <= 1 else state - 1 }
                dataframe = dataframe.append(item, ignore_index=True)

        return dataframe

PBL_Columns = ["Path", "Class"]
dataset = pd.DataFrame(columns=PBL_Columns)
dataset = json_2_dataframe_PBL(dataset, filter_data)

dataset
# Out:
# HBox(children=(IntProgress(value=0, max=51800), HTML(value='')))
#                                                     Path Class
# 0      Dental_Data/PBL/10_seg/10-09-26-173_000408 102...     0
# 1      Dental_Data/PBL/10_seg/10-09-26-190_000408 102...     0
# 2      Dental_Data/PBL/10_seg/10-09-26-201_000408 102...     0
# 3      Dental_Data/PBL/10_seg/10-09-26-248_000408 102...     0
# 4      Dental_Data/PBL/10_seg/10-09-26-263_000408 102...     0
# 5      Dental_Data/PBL/10_seg/10-09-26-279_000408 102...     0
# 6      Dental_Data/PBL/10_seg/10-09-26-301_000408 102...     0
# 7      Dental_Data/PBL/10_seg/10-09-26-317_000408 102...     0
# 8      Dental_Data/PBL/10_seg/10-09-26-332_000408 102...     0
# 9      Dental_Data/PBL/10_seg/10-09-26-332_000408 102...     0
# 10     Dental_Data/PBL/10_seg/10-09-26-348_000408 102...     0
# 11     Dental_Data/PBL/10_seg/10-09-26-364_000408 102...     0
# 12     Dental_Data/PBL/10_seg/10-09-26-379_000408 102...     0
# 13     Dental_Data/PBL/10_seg/10-09-26-395_000408 102...     0
# 14     Dental_Data/PBL/10_seg/10-09-26-401_000408 102...     0
# 15     Dental_Data/PBL/10_seg/10-09-26-417_000408 102...     0
# 16     Dental_Data/PBL/10_seg/10-09-26-433_000408 102...     0
# 17     Dental_Data/PBL/10_seg/10-09-26-433_000408 102...     0
# 18     Dental_Data/PBL/10_seg/10-09-26-448_000408 102...     0
# 19     Dental_Data/PBL/10_seg/10-09-26-464_000408 102...     0
# 20     Dental_Data/PBL/10_seg/10-09-26-479_000408 102...     0
# 21     Dental_Data/PBL/10_seg/10-09-26-502_000408 102...     0
# 22     Dental_Data/PBL/10_seg/10-09-26-517_000408 102...     0
# 23     Dental_Data/PBL/10_seg/10-09-26-533_000408 102...     0
# 24     Dental_Data/PBL/10_seg/10-09-26-548_000408 102...     0
# 25     Dental_Data/PBL/10_seg/10-09-26-564_000408 102...     0
# 26     Dental_Data/PBL/10_seg/10-09-26-580_000408 102...     0
# 27     Dental_Data/PBL/10_seg/10-09-26-602_000408 102...     0
# 28     Dental_Data/PBL/10_seg/10-09-26-617_000408 102...     0
# 29     Dental_Data/PBL/10_seg/10-09-26-633_000408 102...     0
# ...                                                  ...   ...
# 51770  Dental_Data/PBL/10_seg/10-34-48-025_710456 111...     0
# 51771  Dental_Data/PBL/10_seg/10-34-48-048_710456 111...     0
# 51772  Dental_Data/PBL/10_seg/10-34-48-070_710456 111...     0
# 51773  Dental_Data/PBL/10_seg/10-34-48-091_710456 111...     0
# 51774  Dental_Data/PBL/10_seg/10-34-48-113_710456 111...     0
# 51775  Dental_Data/PBL/10_seg/10-34-48-134_710456 111...     0
# 51776  Dental_Data/PBL/10_seg/10-34-48-154_710456 111...     0
# 51777  Dental_Data/PBL/10_seg/10-34-48-177_710456 111...     0
# 51778  Dental_Data/PBL/10_seg/10-34-48-200_710456 111...     0
# 51779  Dental_Data/PBL/10_seg/10-34-48-224_710456 111...     0
# 51780  Dental_Data/PBL/10_seg/10-34-48-782_710456 111...     1
# 51781  Dental_Data/PBL/10_seg/10-34-48-804_710456 111...     1
# 51782  Dental_Data/PBL/10_seg/10-34-48-825_710456 111...     1
# 51783  Dental_Data/PBL/10_seg/10-34-48-847_710456 111...     1
# 51784  Dental_Data/PBL/10_seg/10-34-48-869_710456 111...     1
# 51785  Dental_Data/PBL/10_seg/10-34-48-890_710456 111...     1
# 51786  Dental_Data/PBL/10_seg/10-34-48-913_710456 111...     1
# 51787  Dental_Data/PBL/10_seg/10-34-48-935_710456 111...     1
# 51788  Dental_Data/PBL/10_seg/10-34-48-959_710456 111...     1
# 51789  Dental_Data/PBL/10_seg/10-34-48-982_710456 111...     1
# 51790  Dental_Data/PBL/10_seg/10-34-49-005_710456 111...     1
# 51791  Dental_Data/PBL/10_seg/10-34-49-029_710456 111...     1
# 51792  Dental_Data/PBL/10_seg/10-34-49-054_710456 111...     1
# 51793  Dental_Data/PBL/10_seg/10-34-49-079_710456 111...     1
# 51794  Dental_Data/PBL/10_seg/10-34-49-104_710456 111...     1
# 51795  Dental_Data/PBL/10_seg/10-34-49-128_710456 111...     1
# 51796  Dental_Data/PBL/10_seg/10-34-49-153_710456 111...     1
# 51797  Dental_Data/PBL/10_seg/10-34-49-178_710456 111...     1
# 51798  Dental_Data/PBL/10_seg/10-34-49-203_710456 111...     1
# 51799  Dental_Data/PBL/10_seg/10-34-49-229_710456 111...     1
#
# [51800 rows x 2 columns]

# %% [markdown]
# # Split dataset and guarantee no data pollution

# %%
# data_num = min(len(dataset[dataset["Class"] == 3]), len(dataset[dataset["Class"] == 2]), len(dataset[dataset["Class"] == 1]), len(dataset[dataset["Class"] == 0]))

data_num = min(len(dataset[dataset["Class"] == 2]), len(dataset[dataset["Class"] == 1]), len(dataset[dataset["Class"] == 0]))

# terrible = dataset[dataset["Class"] == 3]
serious = dataset[dataset["Class"] == 2]
medium  = dataset[dataset["Class"] == 1]
healthy = dataset[dataset["Class"] == 0]

# %%
def path_2_images(path_list, resize_setting):
        images = []
        for path in tqdm(path_list):
                image = cv2.imread(path, 0)
                image = cv2.resize(image, resize_setting)
                image = np.reshape(image, (*image.shape, 1))
                images.append(image)
        return np.array(images)

train_range = (0, int( data_num * 0.6 ))
valid_range = (train_range[1], int( data_num * 0.8))
test_range  = (valid_range[1], data_num)

# terrible_train   = terrible.iloc[ train_range[0]: train_range[1], :]
# terrible_valid   = terrible.iloc[ valid_range[0]: valid_range[1], :]
# terrible_test    = terrible.iloc[ test_range[0] : test_range[1] , :]

serious_train   = serious.iloc[ train_range[0]: train_range[1], :]
serious_valid   = serious.iloc[ valid_range[0]: valid_range[1], :]
serious_test    = serious.iloc[ test_range[0] : test_range[1] , :]

medium_train    = medium.iloc[ train_range[0]: train_range[1],  :]
medium_valid    = medium.iloc[ valid_range[0]: valid_range[1],  :]
medium_test     = medium.iloc[ test_range[0] : test_range[1] ,  :]

healthy_train   =  healthy.iloc[ train_range[0]: train_range[1], :]
healthy_valid   =  healthy.iloc[ valid_range[0]: valid_range[1], :]
healthy_test    =  healthy.iloc[ test_range[0] : test_range[1] , :]
 
train_dataset   = pd.concat([healthy_train, medium_train, serious_train])
valid_dataset   = pd.concat([healthy_valid, medium_valid, serious_valid])
test_dataset    = pd.concat([healthy_test , medium_test , serious_test ])

train_dataset = shuffle(train_dataset)
valid_dataset = shuffle(valid_dataset)
test_dataset = shuffle(test_dataset)

resize_setting = (256, 256)

X_train, y_train = path_2_images(train_dataset["Path"], resize_setting), to_categorical(train_dataset["Class"], 3)  
X_val, y_val     = path_2_images(valid_dataset["Path"], resize_setting), to_categorical(valid_dataset["Class"], 3) 
X_test, y_test   = path_2_images(test_dataset ["Path"], resize_setting), to_categorical(test_dataset ["Class"], 3)
# Out:
# HBox(children=(IntProgress(value=0, max=4608), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1536), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1536), HTML(value='')))

# %%
print(X_train.shape)
# Out:
# (4608, 256, 256, 1)

# %%
train_dataset
# Out:
#                                                     Path Class
# 782    Dental_Data/PBL/10_seg/10-09-47-472_000411 112...     0
# 3873   Dental_Data/PBL/10_seg/10-11-01-664_003615 010...     1
# 3602   Dental_Data/PBL/10_seg/10-10-53-023_003615 010...     1
# 1035   Dental_Data/PBL/10_seg/10-09-53-907_001742 082...     0
# 11929  Dental_Data/PBL/10_seg/10-15-27-444_025179_2 1...     1
# 153    Dental_Data/PBL/10_seg/10-09-29-713_000408 102...     0
# 118    Dental_Data/PBL/10_seg/10-09-28-825_000408 102...     1
# 880    Dental_Data/PBL/10_seg/10-09-49-418_000411 112...     0
# 1422   Dental_Data/PBL/10_seg/10-10-02-328_001742 082...     2
# 1875   Dental_Data/PBL/10_seg/10-10-12-551_002456 060...     0
# 13240  Dental_Data/PBL/10_seg/10-15-59-132_026110_2 0...     1
# 401    Dental_Data/PBL/10_seg/10-09-37-210_000408 102...     1
# 22     Dental_Data/PBL/10_seg/10-09-26-517_000408 102...     0
# 11507  Dental_Data/PBL/10_seg/10-15-14-632_025179_1 0...     1
# 12503  Dental_Data/PBL/10_seg/10-15-41-979_026110_1 0...     1
# 17228  Dental_Data/PBL/10_seg/10-17-35-180_051282_1 0...     2
# 17643  Dental_Data/PBL/10_seg/10-17-44-070_051282_1 0...     2
# 704    Dental_Data/PBL/10_seg/10-09-45-635_000411 112...     0
# 11305  Dental_Data/PBL/10_seg/10-15-09-725_022198_2 1...     1
# 1538   Dental_Data/PBL/10_seg/10-10-04-969_001742 082...     0
# 1217   Dental_Data/PBL/10_seg/10-09-57-866_001742 082...     0
# 4885   Dental_Data/PBL/10_seg/10-11-26-070_004151 091...     1
# 26520  Dental_Data/PBL/10_seg/10-23-31-116_111084_2 0...     2
# 1598   Dental_Data/PBL/10_seg/10-10-06-682_001742 082...     0
# 7176   Dental_Data/PBL/10_seg/10-13-04-758_007501 082...     1
# 1143   Dental_Data/PBL/10_seg/10-09-56-356_001742 082...     0
# 11457  Dental_Data/PBL/10_seg/10-15-13-325_025179_1 0...     2
# 438    Dental_Data/PBL/10_seg/10-09-37-935_000408 102...     0
# 1800   Dental_Data/PBL/10_seg/10-10-11-330_002456 060...     0
# 13127  Dental_Data/PBL/10_seg/10-15-56-785_026110_2 0...     1
# ...                                                  ...   ...
# 20475  Dental_Data/PBL/10_seg/10-19-32-580_064768_1 0...     2
# 446    Dental_Data/PBL/10_seg/10-09-38-183_000411 112...     0
# 1755   Dental_Data/PBL/10_seg/10-10-10-572_002456 060...     0
# 800    Dental_Data/PBL/10_seg/10-09-47-923_000411 112...     0
# 3788   Dental_Data/PBL/10_seg/10-10-59-315_003615 010...     1
# 3525   Dental_Data/PBL/10_seg/10-10-51-679_003615 010...     1
# 747    Dental_Data/PBL/10_seg/10-09-46-648_000411 112...     0
# 326    Dental_Data/PBL/10_seg/10-09-35-420_000408 102...     0
# 13771  Dental_Data/PBL/10_seg/10-16-11-273_026110_2 0...     1
# 5001   Dental_Data/PBL/10_seg/10-11-28-795_004151 091...     1
# 810    Dental_Data/PBL/10_seg/10-09-48-049_000411 112...     0
# 823    Dental_Data/PBL/10_seg/10-09-48-295_000411 112...     0
# 17568  Dental_Data/PBL/10_seg/10-17-42-584_051282_1 0...     2
# 11767  Dental_Data/PBL/10_seg/10-15-20-659_025179_1 0...     2
# 12142  Dental_Data/PBL/10_seg/10-15-33-238_025179_2 1...     1
# 467    Dental_Data/PBL/10_seg/10-09-39-384_000411 112...     0
# 2330   Dental_Data/PBL/10_seg/10-10-22-974_002555 042...     1
# 434    Dental_Data/PBL/10_seg/10-09-37-851_000408 102...     0
# 279    Dental_Data/PBL/10_seg/10-09-33-764_000408 102...     0
# 18512  Dental_Data/PBL/10_seg/10-18-22-692_051282_3 1...     2
# 12582  Dental_Data/PBL/10_seg/10-15-43-473_026110_1 0...     2
# 762    Dental_Data/PBL/10_seg/10-09-47-010_000411 112...     0
# 19941  Dental_Data/PBL/10_seg/10-19-12-780_060011_2 0...     2
# 970    Dental_Data/PBL/10_seg/10-09-51-589_000411 112...     0
# 15260  Dental_Data/PBL/10_seg/10-16-43-628_035015_1 0...     2
# 7394   Dental_Data/PBL/10_seg/10-13-11-264_007501 082...     2
# 103    Dental_Data/PBL/10_seg/10-09-28-462_000408 102...     1
# 11522  Dental_Data/PBL/10_seg/10-15-15-004_025179_1 0...     1
# 17690  Dental_Data/PBL/10_seg/10-17-45-270_051282_1 0...     2
# 305    Dental_Data/PBL/10_seg/10-09-34-165_000408 102...     0
#
# [4608 rows x 2 columns]

# %%
def VGG_Net(input_shape, classes):
        model = models.Sequential()
        model.add(Conv2D(512, (3, 3), activation='relu', input_shape=input_shape))
        model.add(MaxPooling2D((2, 2)))
        
        model.add(Conv2D(256, (3, 3), activation='relu'))
        model.add(MaxPooling2D((2, 2)))

        model.add(Conv2D(128, (3, 3), activation='relu'))
        model.add(MaxPooling2D((2, 2)))
        
        model.add(Conv2D(64, (3, 3), activation='relu'))
        model.add(MaxPooling2D((2, 2)))
        
        #model.add(Conv2D(32, (3, 3), activation='relu'))
        #model.add(MaxPooling2D((2, 2)))
        
        model.add(Flatten())
        model.add(Dense(2048, activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(512, activation='relu'))
        model.add(Dropout(0.3))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(classes, activation='softmax'))
        model.compile(loss=keras.losses.categorical_crossentropy,
                      optimizer=keras.optimizers.Adadelta(),
                      metrics=['accuracy'])
        
        return model

# %%
input_shape= (*resize_setting, 1)
classes    = 3
model = VGG_Net(input_shape, classes)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 254, 254, 512)     5120
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 127, 127, 512)     0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 125, 256)     1179904
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 60, 128)       295040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 64)        73792
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              25692160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 28,328,131
# Trainable params: 28,328,131
# Non-trainable params: 0
# _________________________________________________________________

# %%
def plot_result(history):
        plt.style.use('fivethirtyeight')
        plt.figure(figsize=(16,5))
        
        plt.subplot(121)
        plt.title("Loss")
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label = 'Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend(loc='lower right')
        
        plt.subplot(122)
        plt.title("Accuracy")
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label = 'Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.ylim([0.1, 1.5])
        plt.legend(loc='lower right')
        plt.show()

# %%
batch_size = 32
epochs     = 50

callback = tf.keras.callbacks.EarlyStopping(
                monitor="val_accuracy",
                min_delta=0.02,
                patience=10,
                verbose=0,
                mode="auto",
                baseline=None,
                restore_best_weights=False,
)

history = model.fit(X_train, y_train, validation_data=(X_val, y_val), shuffle=True, epochs=epochs, batch_size=batch_size)
# Out:
# Train on 4608 samples, validate on 1536 samples
# Epoch 1/50
# 4608/4608 [==============================] - 43s 9ms/step - loss: 2.6630 - accuracy: 0.3281 - val_loss: 1.2843 - val_accuracy: 0.3236
# Epoch 2/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 1.6555 - accuracy: 0.3568 - val_loss: 1.1742 - val_accuracy: 0.3366
# Epoch 3/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 1.3476 - accuracy: 0.3726 - val_loss: 1.1322 - val_accuracy: 0.3418
# Epoch 4/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 1.2105 - accuracy: 0.3965 - val_loss: 1.1281 - val_accuracy: 0.3613
# Epoch 5/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 1.1715 - accuracy: 0.4125 - val_loss: 1.1143 - val_accuracy: 0.3600
# Epoch 6/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 1.1170 - accuracy: 0.4245 - val_loss: 1.1172 - val_accuracy: 0.3678
# Epoch 7/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 1.0889 - accuracy: 0.4340 - val_loss: 1.1155 - val_accuracy: 0.3724
# Epoch 8/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 1.0617 - accuracy: 0.4644 - val_loss: 1.1046 - val_accuracy: 0.4056
# Epoch 9/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 1.0443 - accuracy: 0.4781 - val_loss: 1.1161 - val_accuracy: 0.3984
# Epoch 10/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 1.0091 - accuracy: 0.4926 - val_loss: 1.1170 - val_accuracy: 0.3919
# Epoch 11/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.9792 - accuracy: 0.5187 - val_loss: 1.1254 - val_accuracy: 0.4056
# Epoch 12/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.9440 - accuracy: 0.5458 - val_loss: 1.1526 - val_accuracy: 0.3809
# Epoch 13/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.9236 - accuracy: 0.5627 - val_loss: 1.1471 - val_accuracy: 0.4108
# Epoch 14/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.9167 - accuracy: 0.5723 - val_loss: 1.1628 - val_accuracy: 0.4128
# Epoch 15/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.8589 - accuracy: 0.6007 - val_loss: 1.1690 - val_accuracy: 0.4167
# Epoch 16/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.8628 - accuracy: 0.6029 - val_loss: 1.1906 - val_accuracy: 0.4069
# Epoch 17/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.8191 - accuracy: 0.6298 - val_loss: 1.2082 - val_accuracy: 0.3978
# Epoch 18/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.7974 - accuracy: 0.6523 - val_loss: 1.2255 - val_accuracy: 0.3997
# Epoch 19/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.7593 - accuracy: 0.6632 - val_loss: 1.2280 - val_accuracy: 0.3952
# Epoch 20/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.7568 - accuracy: 0.6699 - val_loss: 1.2438 - val_accuracy: 0.4082
# Epoch 21/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.7146 - accuracy: 0.6970 - val_loss: 1.2586 - val_accuracy: 0.4004
# Epoch 22/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.7096 - accuracy: 0.6942 - val_loss: 1.2611 - val_accuracy: 0.4049
# Epoch 23/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.6864 - accuracy: 0.7029 - val_loss: 1.2835 - val_accuracy: 0.3880
# Epoch 24/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.6693 - accuracy: 0.7042 - val_loss: 1.3086 - val_accuracy: 0.4030
# Epoch 25/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.6416 - accuracy: 0.7333 - val_loss: 1.3034 - val_accuracy: 0.4056
# Epoch 26/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.6114 - accuracy: 0.7498 - val_loss: 1.3520 - val_accuracy: 0.4010
# Epoch 27/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.5982 - accuracy: 0.7535 - val_loss: 1.3744 - val_accuracy: 0.3952
# Epoch 28/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.5801 - accuracy: 0.7598 - val_loss: 1.4127 - val_accuracy: 0.3900
# Epoch 29/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.5549 - accuracy: 0.7721 - val_loss: 1.3936 - val_accuracy: 0.3965
# Epoch 30/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.5343 - accuracy: 0.7882 - val_loss: 1.4210 - val_accuracy: 0.3887
# Epoch 31/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.5226 - accuracy: 0.7910 - val_loss: 1.4419 - val_accuracy: 0.3906
# Epoch 32/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.5082 - accuracy: 0.7956 - val_loss: 1.4606 - val_accuracy: 0.3874
# Epoch 33/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.4789 - accuracy: 0.8099 - val_loss: 1.4891 - val_accuracy: 0.3926
# Epoch 34/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.4608 - accuracy: 0.8153 - val_loss: 1.5116 - val_accuracy: 0.3913
# Epoch 35/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.4570 - accuracy: 0.8225 - val_loss: 1.4920 - val_accuracy: 0.3978
# Epoch 36/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.4357 - accuracy: 0.8305 - val_loss: 1.5331 - val_accuracy: 0.3952
# Epoch 37/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.4297 - accuracy: 0.8316 - val_loss: 1.5656 - val_accuracy: 0.3887
# Epoch 38/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.4144 - accuracy: 0.8429 - val_loss: 1.6077 - val_accuracy: 0.3848
# Epoch 39/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.3937 - accuracy: 0.8548 - val_loss: 1.5693 - val_accuracy: 0.3887
# Epoch 40/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.3880 - accuracy: 0.8524 - val_loss: 1.6478 - val_accuracy: 0.3809
# Epoch 41/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.3688 - accuracy: 0.8639 - val_loss: 1.5878 - val_accuracy: 0.3809
# Epoch 42/50
# 4608/4608 [==============================] - 39s 8ms/step - loss: 0.3736 - accuracy: 0.8585 - val_loss: 1.6311 - val_accuracy: 0.3757
# Epoch 43/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.3543 - accuracy: 0.8661 - val_loss: 1.6144 - val_accuracy: 0.3802
# Epoch 44/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.3326 - accuracy: 0.8800 - val_loss: 1.7157 - val_accuracy: 0.3822
# Epoch 45/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.3292 - accuracy: 0.8785 - val_loss: 1.6853 - val_accuracy: 0.3711
# Epoch 46/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.2996 - accuracy: 0.8882 - val_loss: 1.7525 - val_accuracy: 0.3737
# Epoch 47/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.2917 - accuracy: 0.8950 - val_loss: 1.7370 - val_accuracy: 0.3711
# Epoch 48/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.2854 - accuracy: 0.8969 - val_loss: 1.7353 - val_accuracy: 0.3704
# Epoch 49/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.2866 - accuracy: 0.8976 - val_loss: 1.7841 - val_accuracy: 0.3770
# Epoch 50/50
# 4608/4608 [==============================] - 38s 8ms/step - loss: 0.2814 - accuracy: 0.8969 - val_loss: 1.7570 - val_accuracy: 0.3698

# %%
plot_result(history)

# %%
def plot_confusion_matrix(confusion_matrix, classes):
        df_cm = pd.DataFrame(confusion_matrix, range(classes), range(classes))
        sns.set(font_scale=1.4)
        sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, cmap='YlGnBu', fmt='g') # font size
        plt.title("Confusion Matrix")
        plt.xlabel('prediction' , fontsize=18)
        plt.ylabel('ground truth', fontsize=18)
        plt.show()

results = model.evaluate(X_test, y_test, verbose=2, batch_size=8)
print("Test Loss = {}\nTest Acc  = {}".format(*results))
prediction = model.predict_classes(X_test, batch_size=8)
y = np.argmax(y_test, axis=1)
confusion = confusion_matrix(y, prediction)
plot_confusion_matrix(confusion, classes)
# Out:
# Test Loss = 2.416278937831521
# Test Acc  = 0.255859375

# %%
if not os.path.isfile("CNN_Net.h5"):
        model.save("CNN_Net.h5")

# %%
def gradcam(model, x, layer_name):
        preds = model.predict(x)
        pred_class = np.argmax(preds[0])


        # 預測分類的輸出向量
        pred_output = model.output[:, pred_class]
#         preds = model.predict(x) 
        
        pred_output = model.output
        conv_layer = model.get_layer(layer_name)
        grads = K.gradients(pred_output, conv_layer.output)[0]
        pooled_grads = K.sum(grads, axis=(0, 1, 2))
        iterate = K.function([model.input], [pooled_grads, conv_layer.output[0]])
        pooled_grads_value, conv_layer_output_value = iterate([x])

        for i in range(pooled_grads_value.shape[0]):
                conv_layer_output_value[:, :, i] *= (pooled_grads_value[i])

        heatmap = np.sum(conv_layer_output_value, axis=-1)
    
        return heatmap

def plot_heatmap(heatmaps, image):
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

        plt.figure(figsize=(16,5))
        for idx, heatmap in enumerate(heatmaps):
                # ReLU
                heatmap = np.maximum(heatmap, 0)

                # normalize
                heatmap /= np.max(heatmap)
                heatmap = cv2.resize(heatmap, (image.shape[1], image.shape[0]))
                heatmap = np.uint8(255 * heatmap)

                plt.subplot(1, 7, idx+1)
                plt.xticks([]), plt.yticks([])
                plt.imshow(image, alpha=0.6)
                plt.imshow(heatmap, cmap='jet', alpha=0.4)
                
        plt.show()

Conv_layers = [ layer.name for layer in model.layers if 'conv' in layer.name ]

same = []
diff = []
for idx, (truth, pred) in enumerate(zip(y, prediction)):
        if truth == pred:
                same.append(idx)
        else:
                diff.append(idx)
same_generator = ( X_test[i] for i in same )
diff_generator = ( X_test[i] for i in diff )

# %%
for idx, i in enumerate(same_generator):
        heatmaps = [ gradcam(model, i.reshape(1, *resize_setting, 1), Conv_layers[-1]) ]
        plot_heatmap(heatmaps, i)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in true_divide

# %%
for idx, i in enumerate(diff_generator):
        heatmaps = [ gradcam(model, i.reshape(1, *resize_setting, 1), Conv_layers[-1]) ]
        plot_heatmap(heatmaps, i)
